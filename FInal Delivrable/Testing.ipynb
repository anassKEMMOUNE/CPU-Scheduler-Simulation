# %% [markdown]
# # 1. Process Class Implementation

# %%
from typing import List
import heapq
import random as rand
import pandas as pd

class Process:
    def __init__(self, id: int, burst_time: int, priority: int, arr_time: int , waiting_time : int = 0, cpu_time_acquired : int  = 0, turnaround_time : int = 0) -> None:
        
        self.id = id
        self.burst_time = burst_time
        self.priority = priority
        self.arrival_time = arr_time

        # waiting time is the time between submission to system and starting execution 

        
        self.waiting_time = 0
        self.cpu_time_acquired = 0
        self.turnaround_time = 0
        

        # this would be relevant for preemptive algorithms
        self.last_running_time = 0
        self.max_waiting_time = 0
        self.age = 0
        


    

    @staticmethod
    def generate_processes(file_name :str, number_of_processes : int ,  max_burst :int , min_burst:int, max_arrival_time:int) -> []:
        file = open(file_name, 'w')
        file.write("id,burst_time,priority,arrival_time,turnaround_time,cpu_time_acquired,waiting_time" + '\n')
        processes = []
        for i in range(number_of_processes):
            
            id = i+1
            priority = rand.randint(-20, 19)
            burst_time = rand.randint(min_burst, max_burst)
            arrival_time = rand.randint(0,max_arrival_time)
            
            process = Process(id, burst_time, priority, arrival_time)
            processes.append(process)
            file.write(str(process) + '\n')

        file.close()
            
        return processes
    
    @staticmethod
    def load_from_csv(file_name : str) -> []:
        processes =  []
        df = pd.read_csv(file_name)
        for _,row in df.iterrows() :
            process = Process(row["id"], row["burst_time"],row["priority"], row["arrival_time"], row["turnaround_time"] , row["cpu_time_acquired"], row["waiting_time"])
            processes.append(process)

        return processes
    

    @staticmethod 
    def save_processes_csv(file_name : str , processes : []) -> None :
        file = open(file_name , 'w')
        file.write("id,burst_time,priority,arrival_time,turnaround_time,cpu_time_acquired,waiting_time" + '\n')
        for process in processes : 
            file.write(str(process) + '\n')
        

    def __lt__(self, other):
        if self.priority != other.priority:
            return self.priority < other.priority
        else:
            return self.id < other.id


    def __str__(self):
        return str(self.id) + ',' + str(self.burst_time) + ',' + str(self.priority) + ',' + str(self.arrival_time) + ',' + str(self.turnaround_time) + ',' + str(self.cpu_time_acquired) +',' + str(self.waiting_time)
    

    def display(self):
        return f"Process {self.id} with burst time {self.burst_time} and priority {self.priority} and arrival time {self.arrival_time} and waiting time {self.waiting_time} and turnaround time {self.turnaround_time}"

# %%
### we will generate a list of processes that will later be used for testing the algorithms
processes = Process.generate_processes("mahmoud.csv", 1000, 20, 1, 100)

# %% [markdown]
# # 2. Batch Scheduling Algorithms

# %% [markdown]
# ## First come first served

# %%
# First_come_First_Served
def First_come_First_Served_2(Processes: List[Process]):
    
    # write the output to a csv file
    file = open("execution.csv", 'w')

    Processes.sort(key=lambda x: (x.arrival_time, x.id))
    
    # Calculate waiting time for each process
    current_time = Processes[0].arrival_time



    for process in Processes:

        
        if process.arrival_time > current_time:
            current_time = process.arrival_time

        file.write(str(process.id) + ',' + str(current_time) + ',')

        
        process.waiting_time = current_time - process.arrival_time
        process.turnaround_time = process.waiting_time + process.burst_time
        current_time += process.burst_time


        file.write(str(current_time) + '\n')

    Processes.sort(key=lambda x: x.id)
    return Processes, current_time

# %%
# load the processes from the csv file
processes = Process.load_from_csv("mahmoud.csv")

# run the priority round robin algorithm
processes, current_time = First_come_First_Served_2(processes)

# %%
for i in processes:
    print(i.display())
# Out:
# Process 1 with burst time 8 and priority 4 and arrival time 71 and waiting time 7008 and turnaround time 7016
# Process 2 with burst time 15 and priority -9 and arrival time 73 and waiting time 7199 and turnaround time 7214
# Process 3 with burst time 19 and priority 18 and arrival time 69 and waiting time 6759 and turnaround time 6778
# Process 4 with burst time 4 and priority 11 and arrival time 80 and waiting time 7984 and turnaround time 7988
# Process 5 with burst time 10 and priority -6 and arrival time 24 and waiting time 2110 and turnaround time 2120
# Process 6 with burst time 2 and priority -5 and arrival time 71 and waiting time 7016 and turnaround time 7018
# Process 7 with burst time 5 and priority -8 and arrival time 53 and waiting time 5126 and turnaround time 5131
# Process 8 with burst time 7 and priority -8 and arrival time 38 and waiting time 3609 and turnaround time 3616
# Process 9 with burst time 8 and priority 12 and arrival time 58 and waiting time 5569 and turnaround time 5577
# Process 10 with burst time 11 and priority -13 and arrival time 41 and waiting time 3949 and turnaround time 3960
# Process 11 with burst time 4 and priority -17 and arrival time 66 and waiting time 6413 and turnaround time 6417
# Process 12 with burst time 4 and priority -13 and arrival time 72 and waiting time 7112 and turnaround time 7116
# Process 13 with burst time 9 and priority -16 and arrival time 90 and waiting time 9091 and turnaround time 9100
# Process 14 with burst time 16 and priority -10 and arrival time 40 and waiting time 3828 and turnaround time 3844
# Process 15 with burst time 16 and priority -14 and arrival time 70 and waiting time 6844 and turnaround time 6860
# Process 16 with burst time 1 and priority 12 and arrival time 3 and waiting time 252 and turnaround time 253
# Process 17 with burst time 6 and priority 14 and arrival time 80 and waiting time 7988 and turnaround time 7994
# Process 18 with burst time 12 and priority -1 and arrival time 99 and waiting time 10026 and turnaround time 10038
# Process 19 with burst time 2 and priority -13 and arrival time 58 and waiting time 5577 and turnaround time 5579
# Process 20 with burst time 17 and priority 2 and arrival time 30 and waiting time 2672 and turnaround time 2689
# Process 21 with burst time 5 and priority 14 and arrival time 37 and waiting time 3477 and turnaround time 3482
# Process 22 with burst time 11 and priority 19 and arrival time 98 and waiting time 9941 and turnaround time 9952
# Process 23 with burst time 10 and priority -11 and arrival time 81 and waiting time 8093 and turnaround time 8103
# Process 24 with burst time 14 and priority 8 and arrival time 3 and waiting time 253 and turnaround time 267
# Process 25 with burst time 7 and priority 7 and arrival time 33 and waiting time 3026 and turnaround time 3033
# Process 26 with burst time 16 and priority -5 and arrival time 85 and waiting time 8543 and turnaround time 8559
# Process 27 with burst time 3 and priority 9 and arrival time 28 and waiting time 2486 and turnaround time 2489
# Process 28 with burst time 12 and priority 12 and arrival time 91 and waiting time 9289 and turnaround time 9301
# Process 29 with burst time 12 and priority 3 and arrival time 28 and waiting time 2489 and turnaround time 2501
# Process 30 with burst time 11 and priority 12 and arrival time 37 and waiting time 3482 and turnaround time 3493
# Process 31 with burst time 2 and priority -13 and arrival time 25 and waiting time 2162 and turnaround time 2164
# Process 32 with burst time 19 and priority -16 and arrival time 94 and waiting time 9588 and turnaround time 9607
# Process 33 with burst time 14 and priority 7 and arrival time 42 and waiting time 4041 and turnaround time 4055
# Process 34 with burst time 11 and priority -17 and arrival time 46 and waiting time 4398 and turnaround time 4409
# Process 35 with burst time 1 and priority 11 and arrival time 97 and waiting time 9860 and turnaround time 9861
# Process 36 with burst time 16 and priority 19 and arrival time 25 and waiting time 2164 and turnaround time 2180
# Process 37 with burst time 15 and priority -8 and arrival time 31 and waiting time 2754 and turnaround time 2769
# Process 38 with burst time 14 and priority -4 and arrival time 1 and waiting time 139 and turnaround time 153
# Process 39 with burst time 7 and priority 7 and arrival time 25 and waiting time 2180 and turnaround time 2187
# Process 40 with burst time 6 and priority 15 and arrival time 34 and waiting time 3173 and turnaround time 3179
# Process 41 with burst time 3 and priority -16 and arrival time 21 and waiting time 1817 and turnaround time 1820
# Process 42 with burst time 2 and priority -10 and arrival time 54 and waiting time 5183 and turnaround time 5185
# Process 43 with burst time 17 and priority -15 and arrival time 7 and waiting time 617 and turnaround time 634
# Process 44 with burst time 16 and priority -15 and arrival time 68 and waiting time 6629 and turnaround time 6645
# Process 45 with burst time 13 and priority 0 and arrival time 50 and waiting time 4799 and turnaround time 4812
# Process 46 with burst time 1 and priority -17 and arrival time 58 and waiting time 5579 and turnaround time 5580
# Process 47 with burst time 15 and priority -18 and arrival time 25 and waiting time 2187 and turnaround time 2202
# Process 48 with burst time 2 and priority -10 and arrival time 41 and waiting time 3960 and turnaround time 3962
# Process 49 with burst time 11 and priority 0 and arrival time 40 and waiting time 3844 and turnaround time 3855
# Process 50 with burst time 18 and priority 8 and arrival time 32 and waiting time 2907 and turnaround time 2925
# Process 51 with burst time 18 and priority 0 and arrival time 35 and waiting time 3300 and turnaround time 3318
# Process 52 with burst time 13 and priority -13 and arrival time 6 and waiting time 493 and turnaround time 506
# Process 53 with burst time 17 and priority 16 and arrival time 75 and waiting time 7422 and turnaround time 7439
# Process 54 with burst time 3 and priority 18 and arrival time 68 and waiting time 6645 and turnaround time 6648
# Process 55 with burst time 1 and priority 0 and arrival time 94 and waiting time 9607 and turnaround time 9608
# Process 56 with burst time 8 and priority 15 and arrival time 59 and waiting time 5734 and turnaround time 5742
# Process 57 with burst time 12 and priority 1 and arrival time 97 and waiting time 9861 and turnaround time 9873
# Process 58 with burst time 3 and priority 17 and arrival time 25 and waiting time 2202 and turnaround time 2205
# Process 59 with burst time 3 and priority -11 and arrival time 91 and waiting time 9301 and turnaround time 9304
# Process 60 with burst time 1 and priority -20 and arrival time 97 and waiting time 9873 and turnaround time 9874
# Process 61 with burst time 6 and priority 10 and arrival time 35 and waiting time 3318 and turnaround time 3324
# Process 62 with burst time 19 and priority 19 and arrival time 25 and waiting time 2205 and turnaround time 2224
# Process 63 with burst time 2 and priority -10 and arrival time 72 and waiting time 7116 and turnaround time 7118
# Process 64 with burst time 9 and priority -5 and arrival time 32 and waiting time 2925 and turnaround time 2934
# Process 65 with burst time 2 and priority -18 and arrival time 37 and waiting time 3493 and turnaround time 3495
# Process 66 with burst time 14 and priority 0 and arrival time 13 and waiting time 1215 and turnaround time 1229
# Process 67 with burst time 11 and priority -7 and arrival time 82 and waiting time 8200 and turnaround time 8211
# Process 68 with burst time 17 and priority 2 and arrival time 49 and waiting time 4714 and turnaround time 4731
# Process 69 with burst time 12 and priority -16 and arrival time 70 and waiting time 6860 and turnaround time 6872
# Process 70 with burst time 9 and priority 0 and arrival time 14 and waiting time 1296 and turnaround time 1305
# Process 71 with burst time 12 and priority 1 and arrival time 6 and waiting time 506 and turnaround time 518
# Process 72 with burst time 12 and priority -16 and arrival time 95 and waiting time 9678 and turnaround time 9690
# Process 73 with burst time 1 and priority -17 and arrival time 13 and waiting time 1229 and turnaround time 1230
# Process 74 with burst time 8 and priority -5 and arrival time 79 and waiting time 7855 and turnaround time 7863
# Process 75 with burst time 19 and priority 16 and arrival time 31 and waiting time 2769 and turnaround time 2788
# Process 76 with burst time 13 and priority 9 and arrival time 92 and waiting time 9425 and turnaround time 9438
# Process 77 with burst time 6 and priority -5 and arrival time 53 and waiting time 5131 and turnaround time 5137
# Process 78 with burst time 3 and priority -16 and arrival time 10 and waiting time 940 and turnaround time 943
# Process 79 with burst time 20 and priority -3 and arrival time 23 and waiting time 1973 and turnaround time 1993
# Process 80 with burst time 15 and priority 11 and arrival time 0 and waiting time 0 and turnaround time 15
# Process 81 with burst time 12 and priority 16 and arrival time 98 and waiting time 9952 and turnaround time 9964
# Process 82 with burst time 11 and priority -15 and arrival time 90 and waiting time 9100 and turnaround time 9111
# Process 83 with burst time 11 and priority -10 and arrival time 31 and waiting time 2788 and turnaround time 2799
# Process 84 with burst time 1 and priority 14 and arrival time 23 and waiting time 1993 and turnaround time 1994
# Process 85 with burst time 1 and priority -19 and arrival time 88 and waiting time 8887 and turnaround time 8888
# Process 86 with burst time 12 and priority -20 and arrival time 91 and waiting time 9304 and turnaround time 9316
# Process 87 with burst time 12 and priority 19 and arrival time 12 and waiting time 1171 and turnaround time 1183
# Process 88 with burst time 4 and priority 0 and arrival time 21 and waiting time 1820 and turnaround time 1824
# Process 89 with burst time 19 and priority -19 and arrival time 50 and waiting time 4812 and turnaround time 4831
# Process 90 with burst time 20 and priority 5 and arrival time 0 and waiting time 15 and turnaround time 35
# Process 91 with burst time 7 and priority 15 and arrival time 24 and waiting time 2120 and turnaround time 2127
# Process 92 with burst time 20 and priority -18 and arrival time 74 and waiting time 7369 and turnaround time 7389
# Process 93 with burst time 3 and priority -2 and arrival time 59 and waiting time 5742 and turnaround time 5745
# Process 94 with burst time 18 and priority -17 and arrival time 90 and waiting time 9111 and turnaround time 9129
# Process 95 with burst time 9 and priority -17 and arrival time 44 and waiting time 4278 and turnaround time 4287
# Process 96 with burst time 20 and priority 8 and arrival time 80 and waiting time 7994 and turnaround time 8014
# Process 97 with burst time 16 and priority -5 and arrival time 67 and waiting time 6525 and turnaround time 6541
# Process 98 with burst time 19 and priority -4 and arrival time 33 and waiting time 3033 and turnaround time 3052
# Process 99 with burst time 5 and priority -17 and arrival time 44 and waiting time 4287 and turnaround time 4292
# Process 100 with burst time 6 and priority 4 and arrival time 0 and waiting time 35 and turnaround time 41
# Process 101 with burst time 11 and priority -13 and arrival time 4 and waiting time 343 and turnaround time 354
# Process 102 with burst time 8 and priority 4 and arrival time 2 and waiting time 192 and turnaround time 200
# Process 103 with burst time 8 and priority -8 and arrival time 48 and waiting time 4593 and turnaround time 4601
# Process 104 with burst time 6 and priority -17 and arrival time 61 and waiting time 5969 and turnaround time 5975
# Process 105 with burst time 3 and priority -19 and arrival time 31 and waiting time 2799 and turnaround time 2802
# Process 106 with burst time 7 and priority 9 and arrival time 80 and waiting time 8014 and turnaround time 8021
# Process 107 with burst time 20 and priority 0 and arrival time 97 and waiting time 9874 and turnaround time 9894
# Process 108 with burst time 18 and priority 2 and arrival time 39 and waiting time 3698 and turnaround time 3716
# Process 109 with burst time 18 and priority -4 and arrival time 10 and waiting time 943 and turnaround time 961
# Process 110 with burst time 20 and priority -13 and arrival time 87 and waiting time 8792 and turnaround time 8812
# Process 111 with burst time 12 and priority -9 and arrival time 99 and waiting time 10038 and turnaround time 10050
# Process 112 with burst time 16 and priority 18 and arrival time 52 and waiting time 5058 and turnaround time 5074
# Process 113 with burst time 3 and priority 8 and arrival time 32 and waiting time 2934 and turnaround time 2937
# Process 114 with burst time 5 and priority 2 and arrival time 11 and waiting time 1084 and turnaround time 1089
# Process 115 with burst time 10 and priority 19 and arrival time 20 and waiting time 1753 and turnaround time 1763
# Process 116 with burst time 5 and priority -10 and arrival time 75 and waiting time 7439 and turnaround time 7444
# Process 117 with burst time 17 and priority -17 and arrival time 61 and waiting time 5975 and turnaround time 5992
# Process 118 with burst time 9 and priority 0 and arrival time 31 and waiting time 2802 and turnaround time 2811
# Process 119 with burst time 17 and priority 16 and arrival time 69 and waiting time 6778 and turnaround time 6795
# Process 120 with burst time 10 and priority -11 and arrival time 16 and waiting time 1421 and turnaround time 1431
# Process 121 with burst time 13 and priority 17 and arrival time 59 and waiting time 5745 and turnaround time 5758
# Process 122 with burst time 13 and priority -1 and arrival time 25 and waiting time 2224 and turnaround time 2237
# Process 123 with burst time 7 and priority -17 and arrival time 31 and waiting time 2811 and turnaround time 2818
# Process 124 with burst time 13 and priority 18 and arrival time 25 and waiting time 2237 and turnaround time 2250
# Process 125 with burst time 14 and priority -10 and arrival time 86 and waiting time 8630 and turnaround time 8644
# Process 126 with burst time 19 and priority -4 and arrival time 87 and waiting time 8812 and turnaround time 8831
# Process 127 with burst time 12 and priority 14 and arrival time 84 and waiting time 8463 and turnaround time 8475
# Process 128 with burst time 3 and priority 2 and arrival time 54 and waiting time 5185 and turnaround time 5188
# Process 129 with burst time 15 and priority 9 and arrival time 41 and waiting time 3962 and turnaround time 3977
# Process 130 with burst time 13 and priority -12 and arrival time 77 and waiting time 7664 and turnaround time 7677
# Process 131 with burst time 17 and priority 1 and arrival time 92 and waiting time 9438 and turnaround time 9455
# Process 132 with burst time 4 and priority 18 and arrival time 14 and waiting time 1305 and turnaround time 1309
# Process 133 with burst time 15 and priority -16 and arrival time 88 and waiting time 8888 and turnaround time 8903
# Process 134 with burst time 7 and priority -8 and arrival time 72 and waiting time 7118 and turnaround time 7125
# Process 135 with burst time 14 and priority -18 and arrival time 25 and waiting time 2250 and turnaround time 2264
# Process 136 with burst time 14 and priority -6 and arrival time 8 and waiting time 741 and turnaround time 755
# Process 137 with burst time 4 and priority 16 and arrival time 87 and waiting time 8831 and turnaround time 8835
# Process 138 with burst time 7 and priority -4 and arrival time 24 and waiting time 2127 and turnaround time 2134
# Process 139 with burst time 17 and priority 6 and arrival time 16 and waiting time 1431 and turnaround time 1448
# Process 140 with burst time 15 and priority 16 and arrival time 70 and waiting time 6872 and turnaround time 6887
# Process 141 with burst time 13 and priority 8 and arrival time 34 and waiting time 3179 and turnaround time 3192
# Process 142 with burst time 10 and priority -12 and arrival time 75 and waiting time 7444 and turnaround time 7454
# Process 143 with burst time 2 and priority 0 and arrival time 43 and waiting time 4138 and turnaround time 4140
# Process 144 with burst time 14 and priority -2 and arrival time 19 and waiting time 1617 and turnaround time 1631
# Process 145 with burst time 2 and priority -12 and arrival time 21 and waiting time 1824 and turnaround time 1826
# Process 146 with burst time 20 and priority 8 and arrival time 70 and waiting time 6887 and turnaround time 6907
# Process 147 with burst time 1 and priority 9 and arrival time 86 and waiting time 8644 and turnaround time 8645
# Process 148 with burst time 1 and priority 19 and arrival time 0 and waiting time 41 and turnaround time 42
# Process 149 with burst time 9 and priority -3 and arrival time 9 and waiting time 863 and turnaround time 872
# Process 150 with burst time 12 and priority 8 and arrival time 81 and waiting time 8103 and turnaround time 8115
# Process 151 with burst time 9 and priority -16 and arrival time 9 and waiting time 872 and turnaround time 881
# Process 152 with burst time 4 and priority 13 and arrival time 66 and waiting time 6417 and turnaround time 6421
# Process 153 with burst time 1 and priority -4 and arrival time 93 and waiting time 9530 and turnaround time 9531
# Process 154 with burst time 20 and priority 12 and arrival time 83 and waiting time 8342 and turnaround time 8362
# Process 155 with burst time 4 and priority -9 and arrival time 61 and waiting time 5992 and turnaround time 5996
# Process 156 with burst time 3 and priority 15 and arrival time 51 and waiting time 4951 and turnaround time 4954
# Process 157 with burst time 7 and priority 12 and arrival time 96 and waiting time 9747 and turnaround time 9754
# Process 158 with burst time 1 and priority 19 and arrival time 92 and waiting time 9455 and turnaround time 9456
# Process 159 with burst time 11 and priority 10 and arrival time 56 and waiting time 5308 and turnaround time 5319
# Process 160 with burst time 20 and priority 18 and arrival time 30 and waiting time 2689 and turnaround time 2709
# Process 161 with burst time 9 and priority 5 and arrival time 49 and waiting time 4731 and turnaround time 4740
# Process 162 with burst time 5 and priority -19 and arrival time 72 and waiting time 7125 and turnaround time 7130
# Process 163 with burst time 5 and priority -13 and arrival time 91 and waiting time 9316 and turnaround time 9321
# Process 164 with burst time 5 and priority -8 and arrival time 90 and waiting time 9129 and turnaround time 9134
# Process 165 with burst time 9 and priority -17 and arrival time 14 and waiting time 1309 and turnaround time 1318
# Process 166 with burst time 11 and priority 1 and arrival time 31 and waiting time 2818 and turnaround time 2829
# Process 167 with burst time 9 and priority 18 and arrival time 76 and waiting time 7558 and turnaround time 7567
# Process 168 with burst time 17 and priority 9 and arrival time 37 and waiting time 3495 and turnaround time 3512
# Process 169 with burst time 6 and priority -6 and arrival time 14 and waiting time 1318 and turnaround time 1324
# Process 170 with burst time 3 and priority 16 and arrival time 12 and waiting time 1183 and turnaround time 1186
# Process 171 with burst time 12 and priority -4 and arrival time 66 and waiting time 6421 and turnaround time 6433
# Process 172 with burst time 20 and priority -17 and arrival time 47 and waiting time 4487 and turnaround time 4507
# Process 173 with burst time 17 and priority -20 and arrival time 59 and waiting time 5758 and turnaround time 5775
# Process 174 with burst time 6 and priority -12 and arrival time 17 and waiting time 1531 and turnaround time 1537
# Process 175 with burst time 3 and priority 17 and arrival time 97 and waiting time 9894 and turnaround time 9897
# Process 176 with burst time 10 and priority 18 and arrival time 47 and waiting time 4507 and turnaround time 4517
# Process 177 with burst time 6 and priority -9 and arrival time 31 and waiting time 2829 and turnaround time 2835
# Process 178 with burst time 12 and priority -14 and arrival time 39 and waiting time 3716 and turnaround time 3728
# Process 179 with burst time 17 and priority 13 and arrival time 5 and waiting time 413 and turnaround time 430
# Process 180 with burst time 3 and priority 7 and arrival time 25 and waiting time 2264 and turnaround time 2267
# Process 181 with burst time 8 and priority -3 and arrival time 58 and waiting time 5580 and turnaround time 5588
# Process 182 with burst time 3 and priority -18 and arrival time 59 and waiting time 5775 and turnaround time 5778
# Process 183 with burst time 5 and priority 17 and arrival time 87 and waiting time 8835 and turnaround time 8840
# Process 184 with burst time 14 and priority -1 and arrival time 17 and waiting time 1537 and turnaround time 1551
# Process 185 with burst time 15 and priority 5 and arrival time 86 and waiting time 8645 and turnaround time 8660
# Process 186 with burst time 7 and priority 19 and arrival time 5 and waiting time 430 and turnaround time 437
# Process 187 with burst time 3 and priority -1 and arrival time 67 and waiting time 6541 and turnaround time 6544
# Process 188 with burst time 15 and priority -17 and arrival time 66 and waiting time 6433 and turnaround time 6448
# Process 189 with burst time 9 and priority 6 and arrival time 80 and waiting time 8021 and turnaround time 8030
# Process 190 with burst time 12 and priority -11 and arrival time 84 and waiting time 8475 and turnaround time 8487
# Process 191 with burst time 17 and priority 5 and arrival time 38 and waiting time 3616 and turnaround time 3633
# Process 192 with burst time 2 and priority -18 and arrival time 21 and waiting time 1826 and turnaround time 1828
# Process 193 with burst time 4 and priority 18 and arrival time 28 and waiting time 2501 and turnaround time 2505
# Process 194 with burst time 4 and priority -12 and arrival time 22 and waiting time 1873 and turnaround time 1877
# Process 195 with burst time 9 and priority -12 and arrival time 80 and waiting time 8030 and turnaround time 8039
# Process 196 with burst time 2 and priority -4 and arrival time 48 and waiting time 4601 and turnaround time 4603
# Process 197 with burst time 20 and priority 7 and arrival time 19 and waiting time 1631 and turnaround time 1651
# Process 198 with burst time 4 and priority 14 and arrival time 73 and waiting time 7214 and turnaround time 7218
# Process 199 with burst time 9 and priority 19 and arrival time 32 and waiting time 2937 and turnaround time 2946
# Process 200 with burst time 3 and priority -1 and arrival time 73 and waiting time 7218 and turnaround time 7221
# Process 201 with burst time 1 and priority -20 and arrival time 26 and waiting time 2329 and turnaround time 2330
# Process 202 with burst time 17 and priority -20 and arrival time 37 and waiting time 3512 and turnaround time 3529
# Process 203 with burst time 14 and priority 18 and arrival time 21 and waiting time 1828 and turnaround time 1842
# Process 204 with burst time 5 and priority -9 and arrival time 74 and waiting time 7389 and turnaround time 7394
# Process 205 with burst time 20 and priority 11 and arrival time 46 and waiting time 4409 and turnaround time 4429
# Process 206 with burst time 4 and priority -14 and arrival time 41 and waiting time 3977 and turnaround time 3981
# Process 207 with burst time 16 and priority -14 and arrival time 33 and waiting time 3052 and turnaround time 3068
# Process 208 with burst time 11 and priority -14 and arrival time 74 and waiting time 7394 and turnaround time 7405
# Process 209 with burst time 19 and priority -14 and arrival time 63 and waiting time 6134 and turnaround time 6153
# Process 210 with burst time 17 and priority -17 and arrival time 62 and waiting time 6046 and turnaround time 6063
# Process 211 with burst time 6 and priority -3 and arrival time 21 and waiting time 1842 and turnaround time 1848
# Process 212 with burst time 7 and priority -11 and arrival time 22 and waiting time 1877 and turnaround time 1884
# Process 213 with burst time 3 and priority 5 and arrival time 60 and waiting time 5856 and turnaround time 5859
# Process 214 with burst time 8 and priority -10 and arrival time 56 and waiting time 5319 and turnaround time 5327
# Process 215 with burst time 3 and priority 13 and arrival time 17 and waiting time 1551 and turnaround time 1554
# Process 216 with burst time 3 and priority -5 and arrival time 64 and waiting time 6234 and turnaround time 6237
# Process 217 with burst time 19 and priority -1 and arrival time 34 and waiting time 3192 and turnaround time 3211
# Process 218 with burst time 10 and priority -11 and arrival time 10 and waiting time 961 and turnaround time 971
# Process 219 with burst time 3 and priority 5 and arrival time 86 and waiting time 8660 and turnaround time 8663
# Process 220 with burst time 17 and priority 17 and arrival time 35 and waiting time 3324 and turnaround time 3341
# Process 221 with burst time 5 and priority 4 and arrival time 59 and waiting time 5778 and turnaround time 5783
# Process 222 with burst time 15 and priority 17 and arrival time 32 and waiting time 2946 and turnaround time 2961
# Process 223 with burst time 5 and priority -10 and arrival time 20 and waiting time 1763 and turnaround time 1768
# Process 224 with burst time 17 and priority -18 and arrival time 59 and waiting time 5783 and turnaround time 5800
# Process 225 with burst time 20 and priority 10 and arrival time 36 and waiting time 3413 and turnaround time 3433
# Process 226 with burst time 1 and priority 4 and arrival time 65 and waiting time 6349 and turnaround time 6350
# Process 227 with burst time 6 and priority -3 and arrival time 65 and waiting time 6350 and turnaround time 6356
# Process 228 with burst time 10 and priority 16 and arrival time 30 and waiting time 2709 and turnaround time 2719
# Process 229 with burst time 14 and priority 8 and arrival time 6 and waiting time 518 and turnaround time 532
# Process 230 with burst time 11 and priority 8 and arrival time 66 and waiting time 6448 and turnaround time 6459
# Process 231 with burst time 20 and priority -8 and arrival time 58 and waiting time 5588 and turnaround time 5608
# Process 232 with burst time 9 and priority -12 and arrival time 95 and waiting time 9690 and turnaround time 9699
# Process 233 with burst time 15 and priority 13 and arrival time 27 and waiting time 2383 and turnaround time 2398
# Process 234 with burst time 9 and priority -14 and arrival time 3 and waiting time 267 and turnaround time 276
# Process 235 with burst time 9 and priority 11 and arrival time 65 and waiting time 6356 and turnaround time 6365
# Process 236 with burst time 7 and priority -20 and arrival time 32 and waiting time 2961 and turnaround time 2968
# Process 237 with burst time 11 and priority 4 and arrival time 63 and waiting time 6153 and turnaround time 6164
# Process 238 with burst time 9 and priority 18 and arrival time 91 and waiting time 9321 and turnaround time 9330
# Process 239 with burst time 3 and priority 4 and arrival time 57 and waiting time 5408 and turnaround time 5411
# Process 240 with burst time 19 and priority -20 and arrival time 67 and waiting time 6544 and turnaround time 6563
# Process 241 with burst time 18 and priority -12 and arrival time 46 and waiting time 4429 and turnaround time 4447
# Process 242 with burst time 10 and priority -5 and arrival time 55 and waiting time 5249 and turnaround time 5259
# Process 243 with burst time 3 and priority -20 and arrival time 52 and waiting time 5074 and turnaround time 5077
# Process 244 with burst time 6 and priority 14 and arrival time 97 and waiting time 9897 and turnaround time 9903
# Process 245 with burst time 3 and priority -13 and arrival time 54 and waiting time 5188 and turnaround time 5191
# Process 246 with burst time 16 and priority 6 and arrival time 72 and waiting time 7130 and turnaround time 7146
# Process 247 with burst time 7 and priority 17 and arrival time 36 and waiting time 3433 and turnaround time 3440
# Process 248 with burst time 2 and priority 10 and arrival time 27 and waiting time 2398 and turnaround time 2400
# Process 249 with burst time 16 and priority 8 and arrival time 71 and waiting time 7018 and turnaround time 7034
# Process 250 with burst time 7 and priority 15 and arrival time 35 and waiting time 3341 and turnaround time 3348
# Process 251 with burst time 18 and priority -5 and arrival time 56 and waiting time 5327 and turnaround time 5345
# Process 252 with burst time 15 and priority 6 and arrival time 68 and waiting time 6648 and turnaround time 6663
# Process 253 with burst time 2 and priority -4 and arrival time 27 and waiting time 2400 and turnaround time 2402
# Process 254 with burst time 11 and priority -17 and arrival time 59 and waiting time 5800 and turnaround time 5811
# Process 255 with burst time 8 and priority -1 and arrival time 61 and waiting time 5996 and turnaround time 6004
# Process 256 with burst time 14 and priority 18 and arrival time 96 and waiting time 9754 and turnaround time 9768
# Process 257 with burst time 18 and priority 10 and arrival time 77 and waiting time 7677 and turnaround time 7695
# Process 258 with burst time 15 and priority -1 and arrival time 41 and waiting time 3981 and turnaround time 3996
# Process 259 with burst time 7 and priority 19 and arrival time 39 and waiting time 3728 and turnaround time 3735
# Process 260 with burst time 18 and priority -20 and arrival time 74 and waiting time 7405 and turnaround time 7423
# Process 261 with burst time 13 and priority -9 and arrival time 40 and waiting time 3855 and turnaround time 3868
# Process 262 with burst time 6 and priority -14 and arrival time 94 and waiting time 9608 and turnaround time 9614
# Process 263 with burst time 9 and priority 17 and arrival time 81 and waiting time 8115 and turnaround time 8124
# Process 264 with burst time 1 and priority 5 and arrival time 79 and waiting time 7863 and turnaround time 7864
# Process 265 with burst time 7 and priority -5 and arrival time 100 and waiting time 10110 and turnaround time 10117
# Process 266 with burst time 6 and priority 3 and arrival time 68 and waiting time 6663 and turnaround time 6669
# Process 267 with burst time 15 and priority -6 and arrival time 18 and waiting time 1574 and turnaround time 1589
# Process 268 with burst time 10 and priority -14 and arrival time 55 and waiting time 5259 and turnaround time 5269
# Process 269 with burst time 7 and priority -5 and arrival time 59 and waiting time 5811 and turnaround time 5818
# Process 270 with burst time 13 and priority -4 and arrival time 19 and waiting time 1651 and turnaround time 1664
# Process 271 with burst time 8 and priority 15 and arrival time 27 and waiting time 2402 and turnaround time 2410
# Process 272 with burst time 18 and priority 17 and arrival time 6 and waiting time 532 and turnaround time 550
# Process 273 with burst time 4 and priority -20 and arrival time 50 and waiting time 4831 and turnaround time 4835
# Process 274 with burst time 19 and priority -16 and arrival time 54 and waiting time 5191 and turnaround time 5210
# Process 275 with burst time 18 and priority 19 and arrival time 73 and waiting time 7221 and turnaround time 7239
# Process 276 with burst time 15 and priority -16 and arrival time 25 and waiting time 2267 and turnaround time 2282
# Process 277 with burst time 12 and priority 12 and arrival time 8 and waiting time 755 and turnaround time 767
# Process 278 with burst time 19 and priority 8 and arrival time 50 and waiting time 4835 and turnaround time 4854
# Process 279 with burst time 18 and priority 14 and arrival time 57 and waiting time 5411 and turnaround time 5429
# Process 280 with burst time 20 and priority 2 and arrival time 86 and waiting time 8663 and turnaround time 8683
# Process 281 with burst time 3 and priority -9 and arrival time 98 and waiting time 9964 and turnaround time 9967
# Process 282 with burst time 2 and priority 2 and arrival time 40 and waiting time 3868 and turnaround time 3870
# Process 283 with burst time 1 and priority 15 and arrival time 69 and waiting time 6795 and turnaround time 6796
# Process 284 with burst time 13 and priority -6 and arrival time 39 and waiting time 3735 and turnaround time 3748
# Process 285 with burst time 14 and priority 2 and arrival time 23 and waiting time 1994 and turnaround time 2008
# Process 286 with burst time 16 and priority -9 and arrival time 67 and waiting time 6563 and turnaround time 6579
# Process 287 with burst time 20 and priority -11 and arrival time 48 and waiting time 4603 and turnaround time 4623
# Process 288 with burst time 3 and priority -16 and arrival time 94 and waiting time 9614 and turnaround time 9617
# Process 289 with burst time 11 and priority 13 and arrival time 43 and waiting time 4140 and turnaround time 4151
# Process 290 with burst time 4 and priority -19 and arrival time 70 and waiting time 6907 and turnaround time 6911
# Process 291 with burst time 17 and priority 8 and arrival time 28 and waiting time 2505 and turnaround time 2522
# Process 292 with burst time 14 and priority -12 and arrival time 5 and waiting time 437 and turnaround time 451
# Process 293 with burst time 10 and priority -8 and arrival time 20 and waiting time 1768 and turnaround time 1778
# Process 294 with burst time 19 and priority -9 and arrival time 38 and waiting time 3633 and turnaround time 3652
# Process 295 with burst time 18 and priority 17 and arrival time 84 and waiting time 8487 and turnaround time 8505
# Process 296 with burst time 14 and priority 6 and arrival time 70 and waiting time 6911 and turnaround time 6925
# Process 297 with burst time 9 and priority -1 and arrival time 17 and waiting time 1554 and turnaround time 1563
# Process 298 with burst time 1 and priority 4 and arrival time 75 and waiting time 7454 and turnaround time 7455
# Process 299 with burst time 20 and priority -6 and arrival time 40 and waiting time 3870 and turnaround time 3890
# Process 300 with burst time 13 and priority 3 and arrival time 3 and waiting time 276 and turnaround time 289
# Process 301 with burst time 7 and priority -2 and arrival time 5 and waiting time 451 and turnaround time 458
# Process 302 with burst time 11 and priority 18 and arrival time 85 and waiting time 8559 and turnaround time 8570
# Process 303 with burst time 10 and priority -19 and arrival time 11 and waiting time 1089 and turnaround time 1099
# Process 304 with burst time 5 and priority -2 and arrival time 30 and waiting time 2719 and turnaround time 2724
# Process 305 with burst time 13 and priority -2 and arrival time 23 and waiting time 2008 and turnaround time 2021
# Process 306 with burst time 12 and priority -9 and arrival time 51 and waiting time 4954 and turnaround time 4966
# Process 307 with burst time 11 and priority -20 and arrival time 19 and waiting time 1664 and turnaround time 1675
# Process 308 with burst time 3 and priority -16 and arrival time 2 and waiting time 200 and turnaround time 203
# Process 309 with burst time 9 and priority 13 and arrival time 77 and waiting time 7695 and turnaround time 7704
# Process 310 with burst time 11 and priority 9 and arrival time 100 and waiting time 10117 and turnaround time 10128
# Process 311 with burst time 14 and priority -6 and arrival time 64 and waiting time 6237 and turnaround time 6251
# Process 312 with burst time 16 and priority -12 and arrival time 23 and waiting time 2021 and turnaround time 2037
# Process 313 with burst time 1 and priority -7 and arrival time 70 and waiting time 6925 and turnaround time 6926
# Process 314 with burst time 12 and priority -5 and arrival time 44 and waiting time 4292 and turnaround time 4304
# Process 315 with burst time 7 and priority 13 and arrival time 33 and waiting time 3068 and turnaround time 3075
# Process 316 with burst time 5 and priority -20 and arrival time 63 and waiting time 6164 and turnaround time 6169
# Process 317 with burst time 11 and priority 9 and arrival time 52 and waiting time 5077 and turnaround time 5088
# Process 318 with burst time 9 and priority 10 and arrival time 76 and waiting time 7567 and turnaround time 7576
# Process 319 with burst time 9 and priority 18 and arrival time 45 and waiting time 4358 and turnaround time 4367
# Process 320 with burst time 6 and priority -1 and arrival time 3 and waiting time 289 and turnaround time 295
# Process 321 with burst time 14 and priority 15 and arrival time 59 and waiting time 5818 and turnaround time 5832
# Process 322 with burst time 3 and priority 9 and arrival time 31 and waiting time 2835 and turnaround time 2838
# Process 323 with burst time 15 and priority -3 and arrival time 37 and waiting time 3529 and turnaround time 3544
# Process 324 with burst time 16 and priority -20 and arrival time 32 and waiting time 2968 and turnaround time 2984
# Process 325 with burst time 5 and priority -9 and arrival time 43 and waiting time 4151 and turnaround time 4156
# Process 326 with burst time 16 and priority -9 and arrival time 90 and waiting time 9134 and turnaround time 9150
# Process 327 with burst time 1 and priority -6 and arrival time 91 and waiting time 9330 and turnaround time 9331
# Process 328 with burst time 5 and priority -12 and arrival time 40 and waiting time 3890 and turnaround time 3895
# Process 329 with burst time 14 and priority 17 and arrival time 6 and waiting time 550 and turnaround time 564
# Process 330 with burst time 10 and priority 14 and arrival time 40 and waiting time 3895 and turnaround time 3905
# Process 331 with burst time 16 and priority -1 and arrival time 84 and waiting time 8505 and turnaround time 8521
# Process 332 with burst time 10 and priority 0 and arrival time 57 and waiting time 5429 and turnaround time 5439
# Process 333 with burst time 14 and priority 13 and arrival time 94 and waiting time 9617 and turnaround time 9631
# Process 334 with burst time 5 and priority -10 and arrival time 16 and waiting time 1448 and turnaround time 1453
# Process 335 with burst time 16 and priority -19 and arrival time 79 and waiting time 7864 and turnaround time 7880
# Process 336 with burst time 3 and priority 7 and arrival time 65 and waiting time 6365 and turnaround time 6368
# Process 337 with burst time 14 and priority -14 and arrival time 4 and waiting time 354 and turnaround time 368
# Process 338 with burst time 7 and priority -13 and arrival time 54 and waiting time 5210 and turnaround time 5217
# Process 339 with burst time 15 and priority -6 and arrival time 66 and waiting time 6459 and turnaround time 6474
# Process 340 with burst time 8 and priority 16 and arrival time 58 and waiting time 5608 and turnaround time 5616
# Process 341 with burst time 1 and priority -6 and arrival time 22 and waiting time 1884 and turnaround time 1885
# Process 342 with burst time 19 and priority -14 and arrival time 81 and waiting time 8124 and turnaround time 8143
# Process 343 with burst time 5 and priority 4 and arrival time 3 and waiting time 295 and turnaround time 300
# Process 344 with burst time 15 and priority 6 and arrival time 70 and waiting time 6926 and turnaround time 6941
# Process 345 with burst time 18 and priority -6 and arrival time 10 and waiting time 971 and turnaround time 989
# Process 346 with burst time 6 and priority 9 and arrival time 59 and waiting time 5832 and turnaround time 5838
# Process 347 with burst time 1 and priority 15 and arrival time 85 and waiting time 8570 and turnaround time 8571
# Process 348 with burst time 15 and priority -6 and arrival time 57 and waiting time 5439 and turnaround time 5454
# Process 349 with burst time 20 and priority -1 and arrival time 0 and waiting time 42 and turnaround time 62
# Process 350 with burst time 6 and priority -6 and arrival time 12 and waiting time 1186 and turnaround time 1192
# Process 351 with burst time 18 and priority 9 and arrival time 33 and waiting time 3075 and turnaround time 3093
# Process 352 with burst time 14 and priority 16 and arrival time 90 and waiting time 9150 and turnaround time 9164
# Process 353 with burst time 12 and priority 3 and arrival time 2 and waiting time 203 and turnaround time 215
# Process 354 with burst time 20 and priority -10 and arrival time 34 and waiting time 3211 and turnaround time 3231
# Process 355 with burst time 10 and priority 11 and arrival time 5 and waiting time 458 and turnaround time 468
# Process 356 with burst time 10 and priority -14 and arrival time 67 and waiting time 6579 and turnaround time 6589
# Process 357 with burst time 3 and priority 8 and arrival time 66 and waiting time 6474 and turnaround time 6477
# Process 358 with burst time 18 and priority -16 and arrival time 71 and waiting time 7034 and turnaround time 7052
# Process 359 with burst time 6 and priority -8 and arrival time 38 and waiting time 3652 and turnaround time 3658
# Process 360 with burst time 3 and priority -2 and arrival time 35 and waiting time 3348 and turnaround time 3351
# Process 361 with burst time 17 and priority 9 and arrival time 7 and waiting time 634 and turnaround time 651
# Process 362 with burst time 8 and priority 7 and arrival time 17 and waiting time 1563 and turnaround time 1571
# Process 363 with burst time 3 and priority -18 and arrival time 77 and waiting time 7704 and turnaround time 7707
# Process 364 with burst time 9 and priority 8 and arrival time 46 and waiting time 4447 and turnaround time 4456
# Process 365 with burst time 7 and priority 6 and arrival time 43 and waiting time 4156 and turnaround time 4163
# Process 366 with burst time 5 and priority -5 and arrival time 64 and waiting time 6251 and turnaround time 6256
# Process 367 with burst time 12 and priority -14 and arrival time 31 and waiting time 2838 and turnaround time 2850
# Process 368 with burst time 4 and priority -1 and arrival time 69 and waiting time 6796 and turnaround time 6800
# Process 369 with burst time 12 and priority 4 and arrival time 35 and waiting time 3351 and turnaround time 3363
# Process 370 with burst time 8 and priority -8 and arrival time 23 and waiting time 2037 and turnaround time 2045
# Process 371 with burst time 4 and priority -17 and arrival time 96 and waiting time 9768 and turnaround time 9772
# Process 372 with burst time 5 and priority -11 and arrival time 67 and waiting time 6589 and turnaround time 6594
# Process 373 with burst time 13 and priority 18 and arrival time 96 and waiting time 9772 and turnaround time 9785
# Process 374 with burst time 16 and priority 0 and arrival time 32 and waiting time 2984 and turnaround time 3000
# Process 375 with burst time 14 and priority 18 and arrival time 53 and waiting time 5137 and turnaround time 5151
# Process 376 with burst time 1 and priority -13 and arrival time 58 and waiting time 5616 and turnaround time 5617
# Process 377 with burst time 17 and priority 17 and arrival time 92 and waiting time 9456 and turnaround time 9473
# Process 378 with burst time 5 and priority 9 and arrival time 51 and waiting time 4966 and turnaround time 4971
# Process 379 with burst time 4 and priority -8 and arrival time 16 and waiting time 1453 and turnaround time 1457
# Process 380 with burst time 20 and priority -6 and arrival time 3 and waiting time 300 and turnaround time 320
# Process 381 with burst time 17 and priority 14 and arrival time 65 and waiting time 6368 and turnaround time 6385
# Process 382 with burst time 6 and priority 14 and arrival time 16 and waiting time 1457 and turnaround time 1463
# Process 383 with burst time 16 and priority -1 and arrival time 71 and waiting time 7052 and turnaround time 7068
# Process 384 with burst time 8 and priority 12 and arrival time 94 and waiting time 9631 and turnaround time 9639
# Process 385 with burst time 14 and priority 18 and arrival time 36 and waiting time 3440 and turnaround time 3454
# Process 386 with burst time 15 and priority 3 and arrival time 71 and waiting time 7068 and turnaround time 7083
# Process 387 with burst time 8 and priority -18 and arrival time 91 and waiting time 9331 and turnaround time 9339
# Process 388 with burst time 5 and priority -3 and arrival time 99 and waiting time 10050 and turnaround time 10055
# Process 389 with burst time 1 and priority -2 and arrival time 21 and waiting time 1848 and turnaround time 1849
# Process 390 with burst time 11 and priority 9 and arrival time 86 and waiting time 8683 and turnaround time 8694
# Process 391 with burst time 1 and priority 11 and arrival time 13 and waiting time 1230 and turnaround time 1231
# Process 392 with burst time 8 and priority -17 and arrival time 77 and waiting time 7707 and turnaround time 7715
# Process 393 with burst time 9 and priority -13 and arrival time 26 and waiting time 2330 and turnaround time 2339
# Process 394 with burst time 16 and priority 2 and arrival time 82 and waiting time 8211 and turnaround time 8227
# Process 395 with burst time 18 and priority -17 and arrival time 5 and waiting time 468 and turnaround time 486
# Process 396 with burst time 14 and priority 10 and arrival time 77 and waiting time 7715 and turnaround time 7729
# Process 397 with burst time 2 and priority -16 and arrival time 80 and waiting time 8039 and turnaround time 8041
# Process 398 with burst time 9 and priority -8 and arrival time 55 and waiting time 5269 and turnaround time 5278
# Process 399 with burst time 10 and priority -18 and arrival time 28 and waiting time 2522 and turnaround time 2532
# Process 400 with burst time 7 and priority 10 and arrival time 72 and waiting time 7146 and turnaround time 7153
# Process 401 with burst time 18 and priority -6 and arrival time 77 and waiting time 7729 and turnaround time 7747
# Process 402 with burst time 10 and priority -12 and arrival time 89 and waiting time 9047 and turnaround time 9057
# Process 403 with burst time 14 and priority -8 and arrival time 62 and waiting time 6063 and turnaround time 6077
# Process 404 with burst time 9 and priority 11 and arrival time 100 and waiting time 10128 and turnaround time 10137
# Process 405 with burst time 13 and priority 11 and arrival time 43 and waiting time 4163 and turnaround time 4176
# Process 406 with burst time 8 and priority 19 and arrival time 84 and waiting time 8521 and turnaround time 8529
# Process 407 with burst time 14 and priority 5 and arrival time 34 and waiting time 3231 and turnaround time 3245
# Process 408 with burst time 16 and priority -6 and arrival time 77 and waiting time 7747 and turnaround time 7763
# Process 409 with burst time 11 and priority 16 and arrival time 93 and waiting time 9531 and turnaround time 9542
# Process 410 with burst time 11 and priority 11 and arrival time 38 and waiting time 3658 and turnaround time 3669
# Process 411 with burst time 15 and priority -15 and arrival time 67 and waiting time 6594 and turnaround time 6609
# Process 412 with burst time 16 and priority 3 and arrival time 88 and waiting time 8903 and turnaround time 8919
# Process 413 with burst time 9 and priority -1 and arrival time 25 and waiting time 2282 and turnaround time 2291
# Process 414 with burst time 13 and priority 3 and arrival time 0 and waiting time 62 and turnaround time 75
# Process 415 with burst time 19 and priority -1 and arrival time 58 and waiting time 5617 and turnaround time 5636
# Process 416 with burst time 15 and priority 15 and arrival time 56 and waiting time 5345 and turnaround time 5360
# Process 417 with burst time 9 and priority -10 and arrival time 12 and waiting time 1192 and turnaround time 1201
# Process 418 with burst time 10 and priority 12 and arrival time 98 and waiting time 9967 and turnaround time 9977
# Process 419 with burst time 18 and priority -6 and arrival time 20 and waiting time 1778 and turnaround time 1796
# Process 420 with burst time 4 and priority -4 and arrival time 73 and waiting time 7239 and turnaround time 7243
# Process 421 with burst time 5 and priority 12 and arrival time 98 and waiting time 9977 and turnaround time 9982
# Process 422 with burst time 13 and priority -18 and arrival time 66 and waiting time 6477 and turnaround time 6490
# Process 423 with burst time 17 and priority -12 and arrival time 82 and waiting time 8227 and turnaround time 8244
# Process 424 with burst time 3 and priority 15 and arrival time 10 and waiting time 989 and turnaround time 992
# ...
# Process 860 with burst time 9 and priority -11 and arrival time 57 and waiting time 5557 and turnaround time 5566
# Process 861 with burst time 11 and priority 2 and arrival time 62 and waiting time 6108 and turnaround time 6119
# Process 862 with burst time 15 and priority 13 and arrival time 11 and waiting time 1116 and turnaround time 1131
# Process 863 with burst time 2 and priority 16 and arrival time 50 and waiting time 4928 and turnaround time 4930
# Process 864 with burst time 17 and priority 6 and arrival time 11 and waiting time 1131 and turnaround time 1148
# Process 865 with burst time 11 and priority -2 and arrival time 19 and waiting time 1739 and turnaround time 1750
# Process 866 with burst time 18 and priority -10 and arrival time 24 and waiting time 2137 and turnaround time 2155
# Process 867 with burst time 2 and priority -9 and arrival time 28 and waiting time 2589 and turnaround time 2591
# Process 868 with burst time 18 and priority -14 and arrival time 82 and waiting time 8303 and turnaround time 8321
# Process 869 with burst time 13 and priority 10 and arrival time 82 and waiting time 8321 and turnaround time 8334
# Process 870 with burst time 5 and priority -20 and arrival time 89 and waiting time 9073 and turnaround time 9078
# Process 871 with burst time 4 and priority 18 and arrival time 100 and waiting time 10166 and turnaround time 10170
# Process 872 with burst time 9 and priority -3 and arrival time 43 and waiting time 4252 and turnaround time 4261
# Process 873 with burst time 6 and priority -7 and arrival time 96 and waiting time 9835 and turnaround time 9841
# Process 874 with burst time 19 and priority -15 and arrival time 56 and waiting time 5386 and turnaround time 5405
# Process 875 with burst time 11 and priority -12 and arrival time 92 and waiting time 9513 and turnaround time 9524
# Process 876 with burst time 13 and priority 15 and arrival time 85 and waiting time 8603 and turnaround time 8616
# Process 877 with burst time 11 and priority 3 and arrival time 75 and waiting time 7517 and turnaround time 7528
# Process 878 with burst time 16 and priority 2 and arrival time 73 and waiting time 7335 and turnaround time 7351
# Process 879 with burst time 12 and priority 11 and arrival time 73 and waiting time 7351 and turnaround time 7363
# Process 880 with burst time 14 and priority 13 and arrival time 72 and waiting time 7164 and turnaround time 7178
# Process 881 with burst time 8 and priority -20 and arrival time 27 and waiting time 2446 and turnaround time 2454
# Process 882 with burst time 3 and priority -12 and arrival time 15 and waiting time 1397 and turnaround time 1400
# Process 883 with burst time 4 and priority -6 and arrival time 15 and waiting time 1400 and turnaround time 1404
# Process 884 with burst time 19 and priority -1 and arrival time 7 and waiting time 707 and turnaround time 726
# Process 885 with burst time 18 and priority 18 and arrival time 6 and waiting time 593 and turnaround time 611
# Process 886 with burst time 8 and priority 7 and arrival time 100 and waiting time 10170 and turnaround time 10178
# Process 887 with burst time 9 and priority -4 and arrival time 75 and waiting time 7528 and turnaround time 7537
# Process 888 with burst time 2 and priority -1 and arrival time 2 and waiting time 246 and turnaround time 248
# Process 889 with burst time 15 and priority 6 and arrival time 98 and waiting time 10011 and turnaround time 10026
# Process 890 with burst time 5 and priority -9 and arrival time 64 and waiting time 6318 and turnaround time 6323
# Process 891 with burst time 12 and priority 11 and arrival time 63 and waiting time 6223 and turnaround time 6235
# Process 892 with burst time 8 and priority 2 and arrival time 69 and waiting time 6837 and turnaround time 6845
# Process 893 with burst time 6 and priority -8 and arrival time 14 and waiting time 1357 and turnaround time 1363
# Process 894 with burst time 18 and priority -12 and arrival time 75 and waiting time 7537 and turnaround time 7555
# Process 895 with burst time 13 and priority -2 and arrival time 27 and waiting time 2454 and turnaround time 2467
# Process 896 with burst time 8 and priority 13 and arrival time 24 and waiting time 2155 and turnaround time 2163
# Process 897 with burst time 2 and priority 18 and arrival time 71 and waiting time 7111 and turnaround time 7113
# Process 898 with burst time 13 and priority 5 and arrival time 100 and waiting time 10178 and turnaround time 10191
# Process 899 with burst time 1 and priority -9 and arrival time 55 and waiting time 5305 and turnaround time 5306
# Process 900 with burst time 12 and priority 6 and arrival time 99 and waiting time 10096 and turnaround time 10108
# Process 901 with burst time 2 and priority 2 and arrival time 87 and waiting time 8881 and turnaround time 8883
# Process 902 with burst time 9 and priority -2 and arrival time 29 and waiting time 2646 and turnaround time 2655
# Process 903 with burst time 2 and priority 0 and arrival time 30 and waiting time 2753 and turnaround time 2755
# Process 904 with burst time 5 and priority -17 and arrival time 87 and waiting time 8883 and turnaround time 8888
# Process 905 with burst time 5 and priority -12 and arrival time 78 and waiting time 7851 and turnaround time 7856
# Process 906 with burst time 19 and priority 12 and arrival time 70 and waiting time 6986 and turnaround time 7005
# Process 907 with burst time 2 and priority 14 and arrival time 97 and waiting time 9940 and turnaround time 9942
# Process 908 with burst time 2 and priority 4 and arrival time 60 and waiting time 5953 and turnaround time 5955
# Process 909 with burst time 9 and priority 0 and arrival time 82 and waiting time 8334 and turnaround time 8343
# Process 910 with burst time 18 and priority 16 and arrival time 29 and waiting time 2655 and turnaround time 2673
# Process 911 with burst time 4 and priority 1 and arrival time 57 and waiting time 5566 and turnaround time 5570
# Process 912 with burst time 17 and priority 18 and arrival time 16 and waiting time 1509 and turnaround time 1526
# Process 913 with burst time 7 and priority -2 and arrival time 6 and waiting time 611 and turnaround time 618
# Process 914 with burst time 20 and priority -2 and arrival time 51 and waiting time 5037 and turnaround time 5057
# Process 915 with burst time 1 and priority -4 and arrival time 45 and waiting time 4398 and turnaround time 4399
# Process 916 with burst time 20 and priority -11 and arrival time 39 and waiting time 3809 and turnaround time 3829
# Process 917 with burst time 6 and priority 4 and arrival time 16 and waiting time 1526 and turnaround time 1532
# Process 918 with burst time 7 and priority -11 and arrival time 73 and waiting time 7363 and turnaround time 7370
# Process 919 with burst time 13 and priority 6 and arrival time 25 and waiting time 2311 and turnaround time 2324
# Process 920 with burst time 20 and priority 11 and arrival time 96 and waiting time 9841 and turnaround time 9861
# Process 921 with burst time 14 and priority 15 and arrival time 89 and waiting time 9078 and turnaround time 9092
# Process 922 with burst time 5 and priority -1 and arrival time 43 and waiting time 4261 and turnaround time 4266
# Process 923 with burst time 19 and priority 16 and arrival time 64 and waiting time 6323 and turnaround time 6342
# Process 924 with burst time 12 and priority 13 and arrival time 11 and waiting time 1148 and turnaround time 1160
# Process 925 with burst time 1 and priority 6 and arrival time 91 and waiting time 9425 and turnaround time 9426
# Process 926 with burst time 1 and priority -12 and arrival time 42 and waiting time 4138 and turnaround time 4139
# Process 927 with burst time 16 and priority 7 and arrival time 62 and waiting time 6119 and turnaround time 6135
# Process 928 with burst time 15 and priority -7 and arrival time 85 and waiting time 8616 and turnaround time 8631
# Process 929 with burst time 19 and priority 13 and arrival time 53 and waiting time 5165 and turnaround time 5184
# Process 930 with burst time 7 and priority 4 and arrival time 79 and waiting time 7978 and turnaround time 7985
# Process 931 with burst time 12 and priority -17 and arrival time 37 and waiting time 3598 and turnaround time 3610
# Process 932 with burst time 4 and priority 12 and arrival time 56 and waiting time 5405 and turnaround time 5409
# Process 933 with burst time 1 and priority -4 and arrival time 86 and waiting time 8772 and turnaround time 8773
# Process 934 with burst time 10 and priority 11 and arrival time 34 and waiting time 3291 and turnaround time 3301
# Process 935 with burst time 13 and priority 11 and arrival time 31 and waiting time 2893 and turnaround time 2906
# Process 936 with burst time 4 and priority -2 and arrival time 17 and waiting time 1571 and turnaround time 1575
# Process 937 with burst time 5 and priority -20 and arrival time 77 and waiting time 7801 and turnaround time 7806
# Process 938 with burst time 6 and priority -17 and arrival time 25 and waiting time 2324 and turnaround time 2330
# Process 939 with burst time 19 and priority 13 and arrival time 88 and waiting time 9015 and turnaround time 9034
# Process 940 with burst time 15 and priority 2 and arrival time 60 and waiting time 5955 and turnaround time 5970
# Process 941 with burst time 1 and priority -15 and arrival time 10 and waiting time 1082 and turnaround time 1083
# Process 942 with burst time 5 and priority -19 and arrival time 38 and waiting time 3694 and turnaround time 3699
# Process 943 with burst time 19 and priority 15 and arrival time 35 and waiting time 3395 and turnaround time 3414
# Process 944 with burst time 16 and priority 8 and arrival time 86 and waiting time 8773 and turnaround time 8789
# Process 945 with burst time 4 and priority 8 and arrival time 21 and waiting time 1870 and turnaround time 1874
# Process 946 with burst time 3 and priority 9 and arrival time 59 and waiting time 5854 and turnaround time 5857
# Process 947 with burst time 12 and priority -4 and arrival time 36 and waiting time 3466 and turnaround time 3478
# Process 948 with burst time 3 and priority 17 and arrival time 55 and waiting time 5306 and turnaround time 5309
# Process 949 with burst time 4 and priority 1 and arrival time 75 and waiting time 7555 and turnaround time 7559
# Process 950 with burst time 18 and priority 2 and arrival time 22 and waiting time 1956 and turnaround time 1974
# Process 951 with burst time 8 and priority -6 and arrival time 64 and waiting time 6342 and turnaround time 6350
# Process 952 with burst time 16 and priority -11 and arrival time 50 and waiting time 4930 and turnaround time 4946
# Process 953 with burst time 6 and priority -10 and arrival time 72 and waiting time 7178 and turnaround time 7184
# Process 954 with burst time 9 and priority 15 and arrival time 18 and waiting time 1591 and turnaround time 1600
# Process 955 with burst time 2 and priority 11 and arrival time 4 and waiting time 396 and turnaround time 398
# Process 956 with burst time 18 and priority 7 and arrival time 18 and waiting time 1600 and turnaround time 1618
# Process 957 with burst time 2 and priority 16 and arrival time 77 and waiting time 7806 and turnaround time 7808
# Process 958 with burst time 8 and priority 10 and arrival time 61 and waiting time 6039 and turnaround time 6047
# Process 959 with burst time 3 and priority 10 and arrival time 99 and waiting time 10108 and turnaround time 10111
# Process 960 with burst time 16 and priority -17 and arrival time 72 and waiting time 7184 and turnaround time 7200
# Process 961 with burst time 6 and priority 7 and arrival time 50 and waiting time 4946 and turnaround time 4952
# Process 962 with burst time 5 and priority 15 and arrival time 83 and waiting time 8459 and turnaround time 8464
# Process 963 with burst time 19 and priority -2 and arrival time 8 and waiting time 836 and turnaround time 855
# Process 964 with burst time 19 and priority -4 and arrival time 49 and waiting time 4769 and turnaround time 4788
# Process 965 with burst time 9 and priority 10 and arrival time 8 and waiting time 855 and turnaround time 864
# Process 966 with burst time 1 and priority -13 and arrival time 98 and waiting time 10026 and turnaround time 10027
# Process 967 with burst time 6 and priority 0 and arrival time 27 and waiting time 2467 and turnaround time 2473
# Process 968 with burst time 13 and priority -9 and arrival time 43 and waiting time 4266 and turnaround time 4279
# Process 969 with burst time 12 and priority 11 and arrival time 23 and waiting time 2099 and turnaround time 2111
# Process 970 with burst time 16 and priority -12 and arrival time 4 and waiting time 398 and turnaround time 414
# Process 971 with burst time 14 and priority -9 and arrival time 68 and waiting time 6737 and turnaround time 6751
# Process 972 with burst time 19 and priority -9 and arrival time 100 and waiting time 10191 and turnaround time 10210
# Process 973 with burst time 2 and priority 0 and arrival time 51 and waiting time 5057 and turnaround time 5059
# Process 974 with burst time 8 and priority 13 and arrival time 47 and waiting time 4586 and turnaround time 4594
# Process 975 with burst time 8 and priority -20 and arrival time 65 and waiting time 6406 and turnaround time 6414
# Process 976 with burst time 7 and priority -3 and arrival time 92 and waiting time 9524 and turnaround time 9531
# Process 977 with burst time 8 and priority 18 and arrival time 41 and waiting time 4018 and turnaround time 4026
# Process 978 with burst time 5 and priority 15 and arrival time 2 and waiting time 248 and turnaround time 253
# Process 979 with burst time 2 and priority -17 and arrival time 10 and waiting time 1083 and turnaround time 1085
# Process 980 with burst time 14 and priority 5 and arrival time 27 and waiting time 2473 and turnaround time 2487
# Process 981 with burst time 16 and priority -8 and arrival time 41 and waiting time 4026 and turnaround time 4042
# Process 982 with burst time 11 and priority -9 and arrival time 9 and waiting time 930 and turnaround time 941
# Process 983 with burst time 16 and priority -20 and arrival time 7 and waiting time 726 and turnaround time 742
# Process 984 with burst time 11 and priority 15 and arrival time 88 and waiting time 9034 and turnaround time 9045
# Process 985 with burst time 8 and priority 16 and arrival time 94 and waiting time 9671 and turnaround time 9679
# Process 986 with burst time 4 and priority 15 and arrival time 86 and waiting time 8789 and turnaround time 8793
# Process 987 with burst time 2 and priority 2 and arrival time 31 and waiting time 2906 and turnaround time 2908
# Process 988 with burst time 6 and priority -16 and arrival time 93 and waiting time 9583 and turnaround time 9589
# Process 989 with burst time 12 and priority -10 and arrival time 11 and waiting time 1160 and turnaround time 1172
# Process 990 with burst time 18 and priority 6 and arrival time 40 and waiting time 3932 and turnaround time 3950
# Process 991 with burst time 4 and priority 9 and arrival time 26 and waiting time 2380 and turnaround time 2384
# Process 992 with burst time 12 and priority 19 and arrival time 49 and waiting time 4788 and turnaround time 4800
# Process 993 with burst time 4 and priority 1 and arrival time 95 and waiting time 9744 and turnaround time 9748
# Process 994 with burst time 9 and priority -12 and arrival time 68 and waiting time 6751 and turnaround time 6760
# Process 995 with burst time 4 and priority -15 and arrival time 19 and waiting time 1750 and turnaround time 1754
# Process 996 with burst time 4 and priority 10 and arrival time 70 and waiting time 7005 and turnaround time 7009
# Process 997 with burst time 19 and priority -17 and arrival time 52 and waiting time 5108 and turnaround time 5127
# Process 998 with burst time 3 and priority 10 and arrival time 88 and waiting time 9045 and turnaround time 9048
# Process 999 with burst time 1 and priority 19 and arrival time 67 and waiting time 6629 and turnaround time 6630
# Process 1000 with burst time 18 and priority -19 and arrival time 15 and waiting time 1404 and turnaround time 1422

# %%
# the average turnaround time
print("The average turnaround time is: ", sum([i.turnaround_time for i in processes]) / len(processes))
# Out:
# The average turnaround time is:  5132.398

# %%
# the average waiting time
print("The average waiting time is: ", sum([i.waiting_time for i in processes]) / len(processes))
# Out:
# The average waiting time is:  5122.088

# %% [markdown]
# ## Shortest job first

# %%
# shortest job first 
def Shortest_Job_First_2(Processes: List[Process]): 
    
    # we will use a heap to store the processes with the highest priority at the top
    # and we will push processes in the heap as they arrive and pop the process with the highest priority

    file = open("execution.csv", 'w')

    heap = []
    heapq.heapify(heap)

    # Sort by arrival time
    Processes.sort(key=lambda x: x.arrival_time)

    
    current_process_idx = 0
    current_time = Processes[0].arrival_time

    # add all processes that have arrived to the heap
    while current_process_idx < len(Processes) and Processes[current_process_idx].arrival_time <= current_time:
        heapq.heappush(heap, (Processes[current_process_idx].burst_time, Processes[current_process_idx]))
        current_process_idx += 1
    


    # Now while the queue is not empty we will take the element with the highest priority and calculate the waiting time and current time after the process finishes
    # and then we will push all processes that have arrived to the heap and repeat the process

    
    while heap:


        
        process = heapq.heappop(heap)

        file.write(str(process[1].id) + ',' + str(current_time) + ',')


        process[1].waiting_time = current_time - process[1].arrival_time
        process[1].turnaround_time = process[1].waiting_time + process[1].burst_time
        current_time += process[1].burst_time

        file.write(str(current_time) + '\n')

        while current_process_idx < len(Processes) and Processes[current_process_idx].arrival_time <= current_time:
            heapq.heappush(heap, (Processes[current_process_idx].burst_time, Processes[current_process_idx]))
            current_process_idx += 1
        
        # now the heap might be empty but there are still processes that have not arrived yet
        # we will update the current time to the arrival time of the next process

        if current_process_idx < len(Processes) and heap == []:
            current_time = Processes[current_process_idx].arrival_time

        # now add the process to the heap
        while current_process_idx < len(Processes) and Processes[current_process_idx].arrival_time <= current_time:
            heapq.heappush(heap, (Processes[current_process_idx].burst_time, Processes[current_process_idx]))
            current_process_idx += 1

    Processes.sort(key=lambda x: x.id)
    return Processes, current_time

# %%
# load the processes from the csv file
processes = Process.load_from_csv("mahmoud.csv")

# %%
# run the priority round robin algorithm
processes, current_time = Shortest_Job_First_2(processes)

# %%
# display the five first processes
counter = 0
for i in processes:
    print(i.display())
    counter += 1
    if counter == 5:
        break
# Out:
# Process 1 with burst time 8 and priority 4 and arrival time 71 and waiting time 1537 and turnaround time 1545
# Process 2 with burst time 15 and priority -9 and arrival time 73 and waiting time 5150 and turnaround time 5165
# Process 3 with burst time 19 and priority 18 and arrival time 69 and waiting time 9223 and turnaround time 9242
# Process 4 with burst time 4 and priority 11 and arrival time 80 and waiting time 412 and turnaround time 416
# Process 5 with burst time 10 and priority -6 and arrival time 24 and waiting time 2468 and turnaround time 2478
# Process 6 with burst time 2 and priority -5 and arrival time 71 and waiting time 37 and turnaround time 39
# Process 7 with burst time 5 and priority -8 and arrival time 53 and waiting time 608 and turnaround time 613
# Process 8 with burst time 7 and priority -8 and arrival time 38 and waiting time 1118 and turnaround time 1125
# Process 9 with burst time 8 and priority 12 and arrival time 58 and waiting time 1590 and turnaround time 1598
# Process 10 with burst time 11 and priority -13 and arrival time 41 and waiting time 2832 and turnaround time 2843

# %%
# the average turnaround time
print("The average turnaround time is: ", sum([i.turnaround_time for i in processes]) / len(processes))
# Out:
# The average turnaround time is:  3409.484

# %%
# the average waiting time
print("The average waiting time is: ", sum([i.waiting_time for i in processes]) / len(processes))
# Out:
# The average waiting time is:  3399.174

# %% [markdown]
# ## Priority scheduling for Batch jobs

# %%
## Priority Scheduling
def Priority_2(Processes: List[Process]):
    
    # we will use a heap to store the processes with the highest priority at the top
    # and we will push processes in the heap as they arrive and pop the process with the highest priority

    heap = []
    heapq.heapify(heap)

    file = open("execution.csv", 'w')

    # Sort by arrival time
    Processes.sort(key=lambda x: x.arrival_time)

    
    current_process_idx = 0
    current_time = Processes[0].arrival_time

    # add all processes that have arrived to the heap
    while current_process_idx < len(Processes) and Processes[current_process_idx].arrival_time <= current_time:
        heapq.heappush(heap, (Processes[current_process_idx].priority, Processes[current_process_idx]))
        current_process_idx += 1
    


    # Now while the queue is not empty we will take the element with the highest priority and calculate the waiting time and current time after the process finishes
    # and then we will push all processes that have arrived to the heap and repeat the process

    
    while heap:
        # print('Trated process:', heap[0][1].id)
        
        process = heapq.heappop(heap)

        file.write(str(process[1].id) + ',' + str(current_time) + ',')
        process[1].waiting_time = current_time - process[1].arrival_time
        process[1].turnaround_time = process[1].waiting_time + process[1].burst_time
        current_time += process[1].burst_time

        file.write(str(current_time) + '\n')

        while current_process_idx < len(Processes) and Processes[current_process_idx].arrival_time <= current_time:
            heapq.heappush(heap, (Processes[current_process_idx].priority, Processes[current_process_idx]))
            current_process_idx += 1
        
        # now the heap might be empty but there are still processes that have not arrived yet
        # we will update the current time to the arrival time of the next process

        if current_process_idx < len(Processes) and heap == []:
            current_time = Processes[current_process_idx].arrival_time

        # now add the process to the heap
        while current_process_idx < len(Processes) and Processes[current_process_idx].arrival_time <= current_time:
            heapq.heappush(heap, (Processes[current_process_idx].priority, Processes[current_process_idx]))
            current_process_idx += 1
            
    Processes.sort(key=lambda x: x.id)
    return Processes, current_time

# %%
# generate random processes
processes = Process.generate_processes("mahmoud.csv", 10, 20, 5, 10)

# load the processes from the csv file
processes = Process.load_from_csv("mahmoud.csv")

# %%
# run the priority round robin algorithm
processes, current_time = Priority_2(processes)

# %% [markdown]
# # 3.Interactive systems Scheduling Algorithms

# %% [markdown]
# ## Priority Round Robin Algorithm

# %%
from collections import deque

def Priority_round_robin_2(processes : List[Process], quantum : int, context_switching_time : int) -> List[Process]:

    # this time we will write to a csv file which process is being executed and at what time
    file = open("execution.csv", 'w')

    processes.sort(key=lambda x: x.arrival_time)

    # the priority classes range from -20 to 19
    queue_list = [deque() for _ in range(40)]

    current_time = processes[0].arrival_time
    process_index = 0
    finished_processes = 0
    n = len(processes)

    prev = -1


    while process_index < n and processes[process_index].arrival_time == current_time:
        queue_list[processes[process_index].priority + 20].append(processes[process_index])
        process_index += 1        


    while finished_processes < n:

        # dipslay a progression bar here and delete it ater each progress
        # ...
        
        progress = finished_processes / n
        bar_length = 30
        bar = '=' * int(progress * bar_length) + '>' + '-' * (bar_length - int(progress * bar_length))
        print(f"\rProgress: [{bar}] {progress * 100:.2f}%", end='', flush=True)




        found = False 
        for i in range(40):
            if len(queue_list[i]) > 0:
                found = True
                process = queue_list[i].popleft()

                if prev == -1:
                    prev = process.id

                
                if context_switching_time != 0 and prev != process.id:
                        file.write("Context_Switch," + str(current_time) + ',')
                        current_time += context_switching_time
                        file.write(str(current_time) + '\n')



                file.write(str(process.id) + ',' + str(current_time) + ',')



                # print("-----> Operating on process ", process.id, " with priority ", process.priority, " at time ", current_time)

                if process.cpu_time_acquired == 0:
                    process.waiting_time = current_time - process.arrival_time

                
                if process.burst_time - process.cpu_time_acquired <= quantum:
                    current_time += process.burst_time - process.cpu_time_acquired
                    process.cpu_time_acquired = process.burst_time
                    process.turnaround_time = current_time - process.arrival_time
                    finished_processes += 1
                    file.write(str(current_time) + '\n')


                    while process_index < n and processes[process_index].arrival_time <= current_time:
                        # print("Added process ", processes[process_index].id, " to queue ")
                        queue_list[processes[process_index].priority + 20].append(processes[process_index])
                        process_index += 1
                    


                else:
                    current_time += quantum
                    process.cpu_time_acquired += quantum
                    file.write(str(current_time) + '\n')


                    while process_index < n and processes[process_index].arrival_time <= current_time:
                        # print("Added process ", processes[process_index].id, " to queue ")
                        queue_list[processes[process_index].priority + 20].append(processes[process_index])
                        process_index += 1
                    queue_list[i].append(process)

                
                prev = process.id
                # print("-----> Finished process ", process.id, " at time ", current_time)
                break

        if not found:
            current_time = processes[process_index].arrival_time
            while process_index < n and processes[process_index].arrival_time == current_time:
                queue_list[processes[process_index].priority + 20].append(processes[process_index])
                process_index += 1

    file.close()

    # sort the processes based on their id
    processes.sort(key=lambda x: x.id)
    return processes, current_time

# %%
# generate random processes
processes = Process.generate_processes("mahmoud.csv", 100, 20, 5, 10)

# %%
# load the processes from the csv file
processes = Process.load_from_csv("mahmoud.csv")

# run the priority round robin algorithm
processes, current_time = Priority_round_robin_2(processes, 2, 1)
# Out:
# Progress: [=============================>-] 99.00%

# %% [markdown]
# ## Round Robin

# %%
from collections import deque

# Round robin Algorithm
def Round_Robin_2(Processes: List[Process], quantum: int, context_switching_time: int):
    
    file = open("execution.csv", 'w')
    file.write("id,arrival_time,finish_time" + '\n')
    Processes.sort(key=lambda x: x.arrival_time)

    current_time = Processes[0].arrival_time
    finished_processes = 0

    queue = deque()


    # current_process_idx is the index of the next process that will arrive
    current_process_idx = 0


    while current_process_idx < len(Processes) and Processes[current_process_idx].arrival_time <= current_time:
        queue.append(Processes[current_process_idx])
        current_process_idx += 1

    prev = -1

    while finished_processes < len(Processes):

        # first we do a context switch 
        

        # we pick the first process in the queue and execute it for the quantum time
        # if the process finishes before the quantum time we will update the current time and the process

        if queue:
            process = queue.popleft()

            if prev == -1:
                prev = process.id

            if context_switching_time != 0 and prev != process.id:
                file.write("Context_Switch," + str(current_time) + ',')
                current_time += context_switching_time
                file.write(str(current_time) + '\n')

            file.write(str(process.id) + ',' + str(current_time) + ',')

            # set the waiting time of the process
            if process.cpu_time_acquired == 0:
                process.waiting_time = current_time - process.arrival_time

            #print("runnnig process", process.id)
            if process.burst_time - process.cpu_time_acquired <= quantum:
                process.cpu_time_acquired = process.burst_time
                current_time += process.burst_time - process.cpu_time_acquired
                process.turnaround_time = current_time - process.arrival_time
                finished_processes += 1

                while current_process_idx < len(Processes) and Processes[current_process_idx].arrival_time <= current_time:
                    queue.append(Processes[current_process_idx])
                    current_process_idx += 1

                
            
            else:
                process.cpu_time_acquired += quantum
                current_time += quantum

                while current_process_idx < len(Processes) and Processes[current_process_idx].arrival_time <= current_time:
                    queue.append(Processes[current_process_idx])
                    current_process_idx += 1
                
                queue.append(process)

            prev = process.id
            file.write(str(current_time) + '\n')

                
        else:
            current_time = Processes[current_process_idx].arrival_time

            while current_process_idx < len(Processes) and Processes[current_process_idx].arrival_time <= current_time:
                    queue.append(Processes[current_process_idx])
                    current_process_idx += 1

        
    Processes.sort(key=lambda x: x.id)
    return Processes, current_time

# %%
# generate random processes
processes = Process.generate_processes("mahmoud.csv", 100, 20, 5, 10)

# load the processes from the csv file
processes = Process.load_from_csv("mahmoud.csv")

# %%
# run the RR algorithm
processes, current_time = Round_Robin_2(processes, 2, 1)

# %% [markdown]
# ## Round Robin with Aging

# %%
def round_robin_with_aging(processes: List[Process], quantum: int, context_switching_time: int) -> List[Process]:
    # this time we will write to a csv file which process is being executed and at what time
    file = open("execution.csv", 'w')

    processes.sort(key=lambda x: x.arrival_time)

    queue = []

    current_time = processes[0].arrival_time
    process_index = 0
    finished_processes = 0
    n = len(processes)

    prev = -1

    while process_index < n and processes[process_index].arrival_time == current_time:
        heapq.heappush(queue, (processes[process_index].age, processes[process_index]))
        process_index += 1

    while finished_processes < n:

        # dipslay a progression bar here and delete it ater each progress
        # ...

        progress = finished_processes / n
        bar_length = 30
        bar = '=' * int(progress * bar_length) + '>' + '-' * (bar_length - int(progress * bar_length))
        print(f"\rProgress: [{bar}] {progress * 100:.2f}%", end='', flush=True)

        if len(queue) == 0:
            current_time = processes[process_index].arrival_time
            while process_index < n and processes[process_index].arrival_time == current_time:
                heapq.heappush(queue, (processes[process_index].age, processes[process_index]))
                process_index += 1

        age, process = heapq.heappop(queue)
        # print("Operating on process ", process.id, " with age ", process.age, " at time ", current_time)
        if prev == -1:
            prev = process.id

        if context_switching_time != 0 and prev != process.id:
            file.write("Context_Switch," + str(current_time) + ',')
            current_time += context_switching_time
            file.write(str(current_time) + '\n')

        file.write(str(process.id) + ',' + str(current_time) + ',')

        if process.burst_time - process.cpu_time_acquired <= quantum:
            current_time += process.burst_time - process.cpu_time_acquired
            process.cpu_time_acquired = process.burst_time
            process.turnaround_time = current_time - process.arrival_time

            process.max_waiting_time = max(process.max_waiting_time, current_time - process.last_running_time)
            process.last_running_time = current_time

            process.total_waiting_time = process.turnaround_time - process.burst_time
            finished_processes += 1
            file.write(str(current_time) + '\n')

            while process_index < n and processes[process_index].arrival_time <= current_time:
                heapq.heappush(queue, (processes[process_index].age, processes[process_index]))
                process_index += 1

        else:
            current_time += quantum
            process.cpu_time_acquired += quantum
            file.write(str(current_time) + '\n')

            process.max_waiting_time = max(process.max_waiting_time, current_time - process.last_running_time)
            process.last_running_time = current_time

            while process_index < n and processes[process_index].arrival_time <= current_time:
                heapq.heappush(queue, (processes[process_index].age, processes[process_index]))
                process_index += 1

            process.age += (process.priority + 21)
            heapq.heappush(queue, (process.age, process))

        prev = process.id

    file.close()

    # compute the waiting time for each process
    for process in processes:
        process.waiting_time = process.turnaround_time - process.burst_time

    # sort the processes based on their id
    processes.sort(key=lambda x: x.id)

    #  write into a csv file.
    file = open("SpecialFile.csv", 'w')


    for process in processes:
        file.write(str(process.max_waiting_time) + ',')
    file.write('\n')
    for process in processes:
        file.write(str(process.waiting_time) + ',')
    file.write('\n')
    for process in processes:
        file.write(str(process.turnaround_time) + ',')

    file.close()

    
    return processes, current_time

# %%
# generate random processes
processes = Process.generate_processes("mahmoud.csv", 100, 20, 5, 10)

# load the processes from the csv file
processes = Process.load_from_csv("mahmoud.csv")

# %%
# run the RR algorithm
processes, current_time = round_robin_with_aging(processes, 2, 1)
